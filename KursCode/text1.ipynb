# %%
from bloch_sphere.animate_bloch import do_or_save_animation, AnimState

@do_or_save_animation('my_animation', save=False, fps=60, preview=True)
# Or
#@do_or_save_animation('my_animation', save='gif', fps=60, preview=True)
#@do_or_save_animation('my_animation', save='mp4', fps=60, preview=True)
def animate(state: AnimState):
    state.x_gate()
    state.y_gate()
    state.s_gate()
    state.s_gate()
    ...
    state.wait()  # Pause at the end
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\MK-Notebook\Desktop\QM\QuantumKursFHKiel2022\KursCode\text1.ipynb Cell 1' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/MK-Notebook/Desktop/QM/QuantumKursFHKiel2022/KursCode/text1.ipynb#ch0000000?line=0'>1</a> from bloch_sphere.animate_bloch import do_or_save_animation, AnimState
#       <a href='vscode-notebook-cell:/c%3A/Users/MK-Notebook/Desktop/QM/QuantumKursFHKiel2022/KursCode/text1.ipynb#ch0000000?line=2'>3</a> @do_or_save_animation('my_animation', save=False, fps=60, preview=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/MK-Notebook/Desktop/QM/QuantumKursFHKiel2022/KursCode/text1.ipynb#ch0000000?line=3'>4</a> # Or
#       <a href='vscode-notebook-cell:/c%3A/Users/MK-Notebook/Desktop/QM/QuantumKursFHKiel2022/KursCode/text1.ipynb#ch0000000?line=4'>5</a> #@do_or_save_animation('my_animation', save='gif', fps=60, preview=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/MK-Notebook/Desktop/QM/QuantumKursFHKiel2022/KursCode/text1.ipynb#ch0000000?line=5'>6</a> #@do_or_save_animation('my_animation', save='mp4', fps=60, preview=True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MK-Notebook/Desktop/QM/QuantumKursFHKiel2022/KursCode/text1.ipynb#ch0000000?line=6'>7</a> def animate(state: AnimState):
#       <a href='vscode-notebook-cell:/c%3A/Users/MK-Notebook/Desktop/QM/QuantumKursFHKiel2022/KursCode/text1.ipynb#ch0000000?line=7'>8</a>     state.x_gate()
#       <a href='vscode-notebook-cell:/c%3A/Users/MK-Notebook/Desktop/QM/QuantumKursFHKiel2022/KursCode/text1.ipynb#ch0000000?line=8'>9</a>     state.y_gate()
#
# File c:\Users\MK-Notebook\AppData\Local\Programs\Python\Python310\lib\site-packages\bloch_sphere\animate_bloch.py:204, in do_or_save_animation.<locals>.wrapper(func)
#     <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=201'>202</a>     with draw.animate_jupyter(draw_frame, delay=1/fps) as anim:
#     <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=202'>203</a>         state = AnimState(anim, fps=fps, draw_args={"style": style})
# --> <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=203'>204</a>         func(state)
#     <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=204'>205</a> return func
#
# c:\Users\MK-Notebook\Desktop\QM\QuantumKursFHKiel2022\KursCode\text1.ipynb Cell 1' in animate(state)
#       <a href='vscode-notebook-cell:/c%3A/Users/MK-Notebook/Desktop/QM/QuantumKursFHKiel2022/KursCode/text1.ipynb#ch0000000?line=7'>8</a> state.x_gate()
#       <a href='vscode-notebook-cell:/c%3A/Users/MK-Notebook/Desktop/QM/QuantumKursFHKiel2022/KursCode/text1.ipynb#ch0000000?line=8'>9</a> state.y_gate()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/MK-Notebook/Desktop/QM/QuantumKursFHKiel2022/KursCode/text1.ipynb#ch0000000?line=9'>10</a> state.s_gate()
#      <a href='vscode-notebook-cell:/c%3A/Users/MK-Notebook/Desktop/QM/QuantumKursFHKiel2022/KursCode/text1.ipynb#ch0000000?line=10'>11</a> state.s_gate()
#      <a href='vscode-notebook-cell:/c%3A/Users/MK-Notebook/Desktop/QM/QuantumKursFHKiel2022/KursCode/text1.ipynb#ch0000000?line=11'>12</a> ...
#
# File c:\Users\MK-Notebook\AppData\Local\Programs\Python\Python310\lib\site-packages\bloch_sphere\animate_bloch.py:106, in AnimState.s_gate(self)
#     <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=104'>105</a> def s_gate(self):
# --> <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=105'>106</a>     self.do_gate('S Gate:', (0, 0, 1), np.pi/2)
#
# File c:\Users\MK-Notebook\AppData\Local\Programs\Python\Python310\lib\site-packages\bloch_sphere\animate_bloch.py:91, in AnimState.do_gate(self, label, axis, radians)
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=88'>89</a> self.fade_in(label, axis)
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=89'>90</a> self.rotate(radians)
# ---> <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=90'>91</a> self.fade_out()
#
# File c:\Users\MK-Notebook\AppData\Local\Programs\Python\Python310\lib\site-packages\bloch_sphere\animate_bloch.py:71, in AnimState.fade_out(self)
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=68'>69</a> for t in self._smooth(0.4):
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=69'>70</a>     self.extra_opacity = 1-t
# ---> <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=70'>71</a>     self._draw_frame()
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=71'>72</a> self.extra_opacity = 0
#
# File c:\Users\MK-Notebook\AppData\Local\Programs\Python\Python310\lib\site-packages\bloch_sphere\animate_bloch.py:39, in AnimState._draw_frame(self)
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=37'>38</a> def _draw_frame(self):
# ---> <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=38'>39</a>     self.anim.draw_frame(self.inner_proj, label=self.label,
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=39'>40</a>                          inner_opacity=self.inner_opacity,
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=40'>41</a>                          extra_opacity=self.extra_opacity,
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=41'>42</a>                          axis=self.axis,
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=42'>43</a>                          idPrefix='{}-d'.format(len(self.anim.frames)),
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/bloch_sphere/animate_bloch.py?line=43'>44</a>                          **self.draw_args)
#
# File c:\Users\MK-Notebook\AppData\Local\Programs\Python\Python310\lib\site-packages\drawSvg\animation.py:22, in Animation.draw_frame(self, *args, **kwargs)
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/drawSvg/animation.py?line=19'>20</a> def draw_frame(self, *args, **kwargs):
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/drawSvg/animation.py?line=20'>21</a>     frame = self.draw_func(*args, **kwargs)
# ---> <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/drawSvg/animation.py?line=21'>22</a>     self.append_frame(frame)
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/drawSvg/animation.py?line=22'>23</a>     return frame
#
# File c:\Users\MK-Notebook\AppData\Local\Programs\Python\Python310\lib\site-packages\drawSvg\animation.py:18, in Animation.append_frame(self, frame)
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/drawSvg/animation.py?line=15'>16</a> def append_frame(self, frame):
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/drawSvg/animation.py?line=16'>17</a>     self.frames.append(frame)
# ---> <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/drawSvg/animation.py?line=17'>18</a>     self.callback(frame)
#
# File c:\Users\MK-Notebook\AppData\Local\Programs\Python\Python310\lib\site-packages\drawSvg\animation.py:61, in AnimationContext.draw_jupyter_frame(self, frame)
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/drawSvg/animation.py?line=58'>59</a>     input('Next?')
#      <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/drawSvg/animation.py?line=59'>60</a> elif self.delay != 0:
# ---> <a href='file:///c%3A/Users/MK-Notebook/AppData/Local/Programs/Python/Python310/lib/site-packages/drawSvg/animation.py?line=60'>61</a>     time.sleep(self.delay)
#
# KeyboardInterrupt:
